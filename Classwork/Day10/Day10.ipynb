# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
df = pd.read_csv("Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
plt.scatter(df['TV'],df['sales'])
plt.title("Scatterplot between TV and Sales")
# Out:
# Text(0.5, 1.0, 'Scatterplot between TV and Sales')

# %%
x = df.iloc[:,1:2].values
x
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
# ...

# %%
y = df.iloc[:,4:5].values
y
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3],
#        [18.5],
#        [12.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [10.6],
#        [ 8.6],
#        [17.4],
#        [ 9.2],
#        [ 9.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [12.5],
#        [ 5.6],
#        [15.5],
#        [ 9.7],
#        [12. ],
#        [15. ],
#        [15.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [ 9.6],
#        [17.4],
#        [ 9.5],
#        [12.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [12.9],
#        [ 8.5],
#        [14.9],
#        [10.6],
#        [23.2],
#        [14.8],
#        [ 9.7],
#        [11.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
# ...

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1,test_size=0.2)

# %%
#Model
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Predicted
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[17.18696362],
#        [16.77798032],
#        [11.51540011],
#        [20.60665526],
#        [19.30579273],
#        [20.77419058],
#        [14.84639657],
#        [15.70871075],
#        [10.2785952 ],
#        [17.41362906],
#        [14.90552669],
#        [10.20961007],
#        [17.37913649],
#        [12.21017895],
#        [17.92609005],
#        [12.99365298],
#        [13.28930355],
#        [21.12404376],
#        [ 8.0612159 ],
#        [17.18203611],
#        [11.74699305],
#        [10.14062494],
#        [ 8.03657835],
#        [12.09191872],
#        [12.36293175],
#        [16.08320147],
#        [ 8.92353007],
#        [19.05941725],
#        [15.01885941],
#        [18.63072392],
#        [18.6208689 ],
#        [18.35478338],
#        [14.17625527],
#        [15.18639473],
#        [19.03970721],
#        [15.91073864],
#        [17.75855473],
#        [13.17597083],
#        [17.48261419],
#        [ 7.76556532]])

# %%
t = model.predict(x_train)
t
# Out:
# array([[ 7.4452772 ],
#        [11.2542421 ],
#        [ 7.72121774],
#        [16.85682048],
#        [ 7.15948165],
#        [14.05799504],
#        [10.65308593],
#        [18.03449526],
#        [16.90116806],
#        [18.10840791],
#        [21.07476866],
#        [12.86553773],
#        [ 7.75571031],
#        [15.79740592],
#        [19.88723886],
#        [14.95972929],
#        [17.56638185],
#        [ 8.03165084],
#        [18.23652315],
#        [ 8.91860256],
#        [13.65886677],
#        [13.66379428],
#        [ 7.06585897],
#        [21.26694154],
#        [20.66578537],
#        [ 7.22846678],
#        [10.75163612],
#        [13.59480914],
#        [17.99507519],
#        [ 8.35193896],
#        [19.74434108],
#        [17.32000637],
#        [20.97129096],
#        [ 7.37629207],
#        [ 7.68179766],
#        [17.1278335 ],
#        [ 7.97252073],
#        [10.56439076],
#        [19.16289495],
#        [13.76234447],
#        [16.05363642],
# ...

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.41535307148347844

# %%
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_test, model.predict(x_test), color='red')
plt.title('TV vs Sales')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
model.coef_
# Out:
# array([[0.0492751]])

# %% [markdown]
# # New Dataset

# %%
df = pd.read_csv("student.csv")
df
# Out:
#      Math  Statistics  Physics
# 0      48          68       63
# 1      62          81       72
# 2      79          80       78
# 3      76          83       79
# 4      59          64       62
# ..    ...         ...      ...
# 995    72          74       70
# 996    73          86       90
# 997    89          87       94
# 998    83          82       78
# 999    66          66       72
#
# [1000 rows x 3 columns]

# %%
# Target = Physics
# Independent = Math & Statistics
x = df.iloc[:,0:2].values
x
# Out:
# array([[48, 68],
#        [62, 81],
#        [79, 80],
#        ...,
#        [89, 87],
#        [83, 82],
#        [66, 66]], dtype=int64)

# %%
y = df.iloc[:,2:3].values
y
# Out:
# array([[ 63],
#        [ 72],
#        [ 78],
#        [ 79],
#        [ 62],
#        [ 85],
#        [ 83],
#        [ 41],
#        [ 80],
#        [ 77],
#        [ 64],
#        [ 90],
#        [ 45],
#        [ 77],
#        [ 70],
#        [ 46],
#        [ 76],
#        [ 44],
#        [ 85],
#        [ 72],
#        [ 53],
#        [ 66],
#        [ 75],
#        [ 49],
#        [ 84],
#        [ 83],
#        [ 68],
#        [ 66],
#        [ 77],
#        [ 78],
#        [ 74],
#        [ 83],
#        [ 72],
#        [ 65],
#        [ 46],
#        [ 66],
#        [ 50],
#        [ 79],
#        [ 68],
#        [ 46],
#        [ 86],
#        [ 70],
#        [ 61],
#        [ 53],
#        [ 72],
#        [ 75],
#        [ 50],
#        [ 77],
#        [100],
#        [ 81],
#        [100],
#        [ 87],
#        [ 78],
#        [ 48],
#        [ 50],
#        [ 44],
#        [ 48],
#        [ 43],
#        [ 67],
#        [ 78],
#        [ 58],
#        [ 91],
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1,test_size=0.2)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([[86.6448958 ],
#        [67.57837632],
#        [71.0526586 ],
#        [65.91245408],
#        [69.4984663 ],
#        [65.13535793],
#        [49.11732935],
#        [69.65549703],
#        [66.86117387],
#        [71.41855628],
#        [80.90727625],
#        [69.65549703],
#        [63.83533338],
#        [76.87282225],
#        [71.82975475],
#        [54.72056857],
#        [38.05982416],
#        [81.69896532],
#        [71.61283032],
#        [67.11534162],
#        [40.63722288],
#        [79.39032726],
#        [97.37374662],
#        [58.03782012],
#        [78.79291223],
#        [74.75845823],
#        [76.61865451],
#        [77.5673743 ],
#        [66.82393056],
#        [69.22970564],
#        [69.81252775],
#        [84.82194283],
#        [61.87800008],
#        [83.54456867],
#        [65.68093673],
#        [79.21870362],
#        [75.66993471],
#        [85.95034375],
#        [78.85280594],
#        [50.3574602 ],
#        [80.22731712],
# ...

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.9075944729185936

# %%
lr.coef_
# Out:
# array([[0.09713702, 0.91147648]])

# %%
figure = plt.figure(figsize=(12,6))
plt.scatter(df['Math'], df['Statistics'], df['Physics'], c='blue', marker='o', label='X1 vs X2 vs Y')
plt.plot(y_test,y_pred,color="red")
plt.title("Actual vs Predict")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Math'], df['Statistics'], df['Physics'], c='blue', marker='o', label='X1 vs X2 vs Y')
#plt.plot(y_test,y_pred,color="red")
ax.set_xlabel('Math')
ax.set_ylabel('Statistics')
ax.set_zlabel('Physics')

ax.set_title('3D Scatter Plot for Multiple Regression')
ax.legend()
plt.show()

# %% [markdown]
# # Ridge and Lasso Regression

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %%
cal = fetch_california_housing()

# %%
df = pd.DataFrame(cal.data,columns=cal.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
x=cal.data
x
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
y=cal.target
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
#Train Test Split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.2)

# %%
(x_train.shape,y_train.shape,x_test.shape,y_train.shape)
# Out:
# ((16512, 8), (16512,), (4128, 8), (16512,))

# %%
# Ridge Regression
from sklearn.linear_model import Ridge,Lasso
from sklearn.metrics import mean_squared_error

# %%
ridge_model = Ridge(alpha=0.1)
ridge_model.fit(x_train,y_train)
y_pred = ridge_model.predict(x_test)
mean_squared_error(y_test,y_pred)
# Out:
# 0.5558827543113765

# %%
# Lasso Regression
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(x_train,y_train)
y_pred = lasso_model.predict(x_test)
mean_squared_error(y_test,y_pred)
# Out:
# 0.6135115198058131
