# %% [markdown]
# # Market Basket Analysis

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_excel("Online_Retail.xlsx")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df["Description"].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df["Country"].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Dropping Customer ID
df.drop("CustomerID",axis=1,inplace=True)

# %%
# Removing white spaces from Description
df["Description"] = df["Description"].str.strip()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice         Country Invoice
# ...

# %%
df["InvoiceNo"].str.contains('C').sum()
# Out:
# 0

# %%
df["InvoiceNo"]=df["InvoiceNo"].astype("str")

# %%
df = df[~df["InvoiceNo"].str.contains("C")]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice         Country
# ...

# %%
france=df[df["Country"]=="France"]

# %%
france
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727         ALARM CLOCK BAKELIKE RED        24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                  STARS GIFT TAPE        24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice Country
# 26     2010-12-01 08:45:00       3.75  France
# ...

# %%
france.shape
# Out:
# (8408, 7)

# %%
france.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
basket = france.groupby(["InvoiceNo","Description"])["Quantity"].sum().unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
def encode_data(x):
    if x<=0:
        return 0
    else:
        return 1
encoded_basket = basket.applymap(encode_data)
encoded_basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# 580986                            0                           0
# 581001                            0                           0
# 581171                            0                           0
# 581279                            0                           0
# 581587                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# ...

# %%
frequent_itemsets = apriori(encoded_basket,min_support=0.07,use_colnames=True)
# Out:
# C:\Users\ASUS\anaconda03\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4   0.081633                     (BAKING SET 9 PIECE RETROSPOT)
# ..       ...                                                ...
# 85  0.084184  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
# 86  0.084184  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
# 87  0.102041  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE, SET/6 R...
# 88  0.099490  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 89  0.081633  (SET/20 RED RETROSPOT PAPER NAPKINS, POSTAGE, ...
#
# [90 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets,metric="lift",min_threshold=1)
rules
# Out:
#                                            antecedents  \
# 0                         (ALARM CLOCK BAKELIKE GREEN)
# 1                          (ALARM CLOCK BAKELIKE PINK)
# 2                           (ALARM CLOCK BAKELIKE RED)
# 3                         (ALARM CLOCK BAKELIKE GREEN)
# 4                                            (POSTAGE)
# ..                                                 ...
# 135  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 136               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 137                                          (POSTAGE)
# 138                      (SET/6 RED SPOTTY PAPER CUPS)
# 139                    (SET/6 RED SPOTTY PAPER PLATES)
#
#                                            consequents  antecedent support  \
# 0                          (ALARM CLOCK BAKELIKE PINK)            0.096939
# 1                         (ALARM CLOCK BAKELIKE GREEN)            0.102041
# 2                         (ALARM CLOCK BAKELIKE GREEN)            0.094388
# ...

# %%
rules1 = association_rules(frequent_itemsets,metric="confidence",min_threshold=1)

# %%
rules1
# Out:
#                     antecedents consequents  antecedent support  \
# 0  (JUMBO BAG WOODLAND ANIMALS)   (POSTAGE)            0.076531
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.765306  0.076531         1.0  1.306667  0.017961         inf
#
#    zhangs_metric
# 0       0.254144

# %% [markdown]
# # Natural Language Processing (NLP)

# %%
import nltk
nltk.download('punkt')
sent = "PCA allows for dimensionality reduction by retaining only a subset of the principal components that capture the majority of"
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenization
nltk.sent_tokenize(sent)
# Out:
# ['PCA allows for dimensionality reduction by retaining only a subset of the principal components that capture the majority of']

# %%
tokens = nltk.word_tokenize(sent)
tokens
# Out:
# ['PCA',
#  'allows',
#  'for',
#  'dimensionality',
#  'reduction',
#  'by',
#  'retaining',
#  'only',
#  'a',
#  'subset',
#  'of',
#  'the',
#  'principal',
#  'components',
#  'that',
#  'capture',
#  'the',
#  'majority',
#  'of']

# %%
from nltk.util import bigrams,trigrams

# %%
list(bigrams(tokens))
# Out:
# [('PCA', 'allows'),
#  ('allows', 'for'),
#  ('for', 'dimensionality'),
#  ('dimensionality', 'reduction'),
#  ('reduction', 'by'),
#  ('by', 'retaining'),
#  ('retaining', 'only'),
#  ('only', 'a'),
#  ('a', 'subset'),
#  ('subset', 'of'),
#  ('of', 'the'),
#  ('the', 'principal'),
#  ('principal', 'components'),
#  ('components', 'that'),
#  ('that', 'capture'),
#  ('capture', 'the'),
#  ('the', 'majority'),
#  ('majority', 'of')]

# %%
list(trigrams(tokens))
# Out:
# [('PCA', 'allows', 'for'),
#  ('allows', 'for', 'dimensionality'),
#  ('for', 'dimensionality', 'reduction'),
#  ('dimensionality', 'reduction', 'by'),
#  ('reduction', 'by', 'retaining'),
#  ('by', 'retaining', 'only'),
#  ('retaining', 'only', 'a'),
#  ('only', 'a', 'subset'),
#  ('a', 'subset', 'of'),
#  ('subset', 'of', 'the'),
#  ('of', 'the', 'principal'),
#  ('the', 'principal', 'components'),
#  ('principal', 'components', 'that'),
#  ('components', 'that', 'capture'),
#  ('that', 'capture', 'the'),
#  ('capture', 'the', 'majority'),
#  ('the', 'majority', 'of')]

# %%
# POS(Part Of Speech) tagging
nltk.pos_tag(tokens)
# Out:
# [('PCA', 'NNP'),
#  ('allows', 'VBZ'),
#  ('for', 'IN'),
#  ('dimensionality', 'NN'),
#  ('reduction', 'NN'),
#  ('by', 'IN'),
#  ('retaining', 'VBG'),
#  ('only', 'RB'),
#  ('a', 'DT'),
#  ('subset', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('principal', 'JJ'),
#  ('components', 'NNS'),
#  ('that', 'WDT'),
#  ('capture', 'VBP'),
#  ('the', 'DT'),
#  ('majority', 'NN'),
#  ('of', 'IN')]

# %%
sent= "Jim eats a banana"

# %%
token = nltk.word_tokenize(sent)
token
# Out:
# ['Jim', 'eats', 'a', 'banana']

# %%
nltk.pos_tag(token)
# Out:
# [('Jim', 'NNP'), ('eats', 'VBZ'), ('a', 'DT'), ('banana', 'NN')]

# %%
for i in token:
    print(nltk.pos_tag([i])) # This shows that eats is a Noun
# Out:
# [('Jim', 'NNP')]
# [('eats', 'NNS')]
# [('a', 'DT')]
# [('banana', 'NN')]

# %%
from nltk.tokenize import RegexpTokenizer

# %%
reg = RegexpTokenizer('(?u)\W+|\$[\d\.]+|\S+')
r_tokens = reg.tokenize(sent)
for i in r_tokens:
    print(nltk.pos_tag([i]))
# Out:
# [('Jim', 'NNP')]
# [(' ', 'NN')]
# [('eats', 'NNS')]
# [(' ', 'NN')]
# [('a', 'DT')]
# [(' ', 'NN')]
# [('banana', 'NN')]

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
sent = "In this example, the chatbot serves as an automated assistant that handles customer inquiries, providing timely and accurate responses to common questions. By implementing a chatbot, you can improve the efficiency of your customer service operations, reduce response times, and enhance the overall customer experience on your website."
sent = sent.lower()
sent
# Out:
# 'in this example, the chatbot serves as an automated assistant that handles customer inquiries, providing timely and accurate responses to common questions. by implementing a chatbot, you can improve the efficiency of your customer service operations, reduce response times, and enhance the overall customer experience on your website.'

# %%
tokens = nltk.word_tokenize(sent)
tokens
# Out:
# ['in',
#  'this',
#  'example',
#  ',',
#  'the',
#  'chatbot',
#  'serves',
#  'as',
#  'an',
#  'automated',
#  'assistant',
#  'that',
#  'handles',
#  'customer',
#  'inquiries',
#  ',',
#  'providing',
#  'timely',
#  'and',
#  'accurate',
#  'responses',
#  'to',
#  'common',
#  'questions',
#  '.',
#  'by',
#  'implementing',
#  'a',
#  'chatbot',
#  ',',
#  'you',
#  'can',
#  'improve',
#  'the',
#  'efficiency',
#  'of',
#  'your',
#  'customer',
#  'service',
#  'operations',
#  ',',
#  'reduce',
#  'response',
#  'times',
#  ',',
#  'and',
#  'enhance',
#  'the',
#  'overall',
#  'customer',
#  'experience',
#  'on',
#  'your',
#  'website',
#  '.']

# %%
r=[]
for i in tokens:
    if i not in stopwords.words('english') and i not in [",","."]:
        r.append(i)
r
# Out:
# ['example',
#  'chatbot',
#  'serves',
#  'automated',
#  'assistant',
#  'handles',
#  'customer',
#  'inquiries',
#  'providing',
#  'timely',
#  'accurate',
#  'responses',
#  'common',
#  'questions',
#  'implementing',
#  'chatbot',
#  'improve',
#  'efficiency',
#  'customer',
#  'service',
#  'operations',
#  'reduce',
#  'response',
#  'times',
#  'enhance',
#  'overall',
#  'customer',
#  'experience',
#  'website']

# %%
len(r)
# Out:
# 29

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer, WordNetLemmatizer
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# True

# %%
ps = PorterStemmer()

# %%
ls = LancasterStemmer()

# %%
ss = SnowballStemmer('english')

# %%
ps.stem('chocolate'),ls.stem('chocolate'),ss.stem('chocolate')
# Out:
# ('chocol', 'chocol', 'chocol')

# %%
# Lemmitization
lem = WordNetLemmatizer()

# %%
lem.lemmatize("playing",pos='v')
# Out:
# 'play'
